# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filepath = r'C:\Users\Eric\Desktop\Yb Simulation\twenty_run\run2\temperature.dat'
df = pd.read_csv(filepath, delim_whitespace=True, skiprows=2, names=['TimeStep', 'v_atemp'])

# %%
time = df['TimeStep']
temperature = df['v_atemp']

# %%
plt.figure(dpi=500)
plt.plot(df['TimeStep'], df['v_atemp'], marker='o', linestyle='-', color='b',markersize=0.3)  
plt.title('Annealing_491357_run1_step80000')  
plt.xlabel('TimeStep') 
plt.ylabel('Temperature')  

plt.show()

# %%
print(df)
# Out:
#      TimeStep     v_atemp
# 0        2000  5712.59000
# 1        4000  5937.82000
# 2        6000  5893.45000
# 3        8000  5852.26000
# 4       10000  5823.83000
# ..        ...         ...
# 515   1032000    10.13440
# 516   1034000    10.05070
# 517   1036000    10.16380
# 518   1038000    10.21300
# 519   1040000     9.99609
#
# [520 rows x 2 columns]
